# %% [markdown]
# # **클래스**
#
#   -설계도
#
#   -메서드를 정의
#
# # **인스턴스**
#
#   -제품
#
#   -메서드를 호출
#
# # **메서드**
#
# **클래스 내의 함수**
#
# 좋은코드
# -> 중복의 제거 -> 메서드를 사용
#
#
# 중복되는 코드의
# 반복적인 프로그래밍을 피할 수 있기 때문.
# ```
# 다른 프로그래밍 언어에는 함수가 별도로 존재
#
# 하지만 자바는 클래스를 떠나 존재하는 것이
# 있을 수 없기 때문에
# 자바의 함수는 따로 존재 하지 않고 클래스 내에 존재
#
# 이러한 클래스 내의 함수를 메서드(method)라고 부름.
#
# 메소드를 작성할 때는 되도록 하나의 메소드가 하나의 기능만을 수행하도록 작성하는 것이 좋음
# ```
#
#
#     -유지보수 편리성
#     -재활용성
#     -가독성
#
# # **객체**
#
# 변수와 메서드의 집합
#
# 프로그램 안의 프로그램
#
#
# -- 데이터와 연관 메서드를 어떻게 grouping할것인가?
#
# -> 객체 지향

# %% [markdown]
# **자바스크립트 객체**
#
#
# 자바스크립트의 기본 타입(data type)은 객체(object)
#
#
#
# 객체란 이름(name)과 값(value)으로 구성된 프로퍼티(property)의 정렬되지 않은 집합
#
# 프로퍼티의 값으로 함수가 올 수도 있는데, 이러한 프로퍼티를 메소드(method)라 함
#
# **객체의 프로퍼티 참조**
#
# 객체이름.프로퍼티이름
#
# 또는
#
# 객체이름["프로퍼티이름"]
#
# **객체의 메소드 참조**
#
# 객체이름.메소드이름()
#
#
# **객체의 생성**
#
# 자바스크립트에서 객체를 생성하는 방법은 다음과 같음
#
#
#
# 1. 리터럴 표기(literal notation)를 이용한 방법
# 2. 생성자 함수(constructor function)를 이용한 방법
# 3. Object.create() 메소드를 이용한 방법
#
#
#
# 위와 같은 방법으로 생성되어 메모리에 대입된 객체를 인스턴스(instance)라고 함
#
#
#
#
#   - 1. 리터럴 표기를 이용한 객체의 생성
# 자바스크립트에서 객체를 생성하는 가장 쉬운 방법
#
# ```
# var 객체이름 = {
#     프로퍼티1이름 : 프로퍼티1의값,
#     프로퍼티2이름 : 프로퍼티2의값,
#     ...
# };
# ```
#
#
# 각각의 프로퍼티는 이름과 값을 콜론(:)으로 연결하고, 쉼표(,)를 사용해 다른 프로퍼티와 구분
#
# 프로퍼티의 이름으로는 자바스크립트의 식별자(identifier)나 문자열을 사용할 수 있음
#
#   - 2. 생성자를 이용한 객체의 생성
#
#   new 연산자를 사용하여 객체를 생성하고 초기화할 수 있음
#
#   이 때 사용되는 메소드를 생성자(constructor)라고 하며, 이 메소드는 새롭게 생성되는 객체를 초기화하는 역할을 함
#
# 자바스크립트는 원시 타입을 위한 생성자를 미리 정의하여 제공
#
# ```
# var day = new Date(); ///// new 연산자를 사용하여 Date 타입의 객체를 생성함.
# document.write("올해는 " + day.getFullYear() + "년입니다.");
# ```
#
# 자바스크립트에서 제공하는 생성자를 사용할 수도 있으며, 사용자가 직접 객체 생성자 함수(object constructor function)를 작성하여 사용할 수도 있음
#
#  - 3. Object.create() 메소드를 이용한 객체의 생성
#
#  Object.create() 메소드를 이용하여 객체를 생성할 수도 있음
#  Object.create() 메소드는 지정된 프로토타입(prototype) 객체와 프로퍼티를 가지고 새로운 객체를 만들어 줌
#
#  따라서 이 메소드를 이용하면 사용자가 프로토타입 객체를 직접 명시할 수 있으므로, 상당히 유용하게 사용됨
#
#  ```
#  Object.create(프로토타입객체[, 새로운객체의프로퍼티1, 새로운객체의프로퍼티2, ...]);
#  ```
#
#  Object.create() 메소드의 첫 번째 인수로는 프로토타입으로 사용할 객체를 전달합니다.
#
# 두 번째 인수로는 새로운 객체의 추가할 프로퍼티 정보를 전달
# ```
# var obj = Object.create(null, {             // null 프로토타입을 사용하여 새로운 객체를 만들고
#
#     x: { value: 100, enumerable: true },    // x좌표를 나타내는 열거할 수 있는 프로퍼티와
#     y: { value: 200, enumerable: true }     // y좌표를 나타내는 열거할 수 있는 프로퍼티를 추가함.
#
# });
#
# obj.x;                      // x좌표
# obj.y;                      // y좌표
#
# Object.getPrototypeOf(obj); // 객체의 프로토타입을 반환해 줌.
# ```

# %% [markdown]
# # **public static void main(String[] args)**
#
# **프로그램의 진입점(entry point)을 나타내는 특별한 메소드**
#
#
# **public**: main 메소드는 어디에서나 접근할 수 있어야 함
#
# 따라서 다른 클래스나 패키지에서도 접근 가능
#
# **static**: main 메소드는 정적 메소드로 선언되어야 함
#
# 이는 인스턴스 생성 없이 클래스 이름을 통해 직접 호출할 수 있다는 의미
#
# **void**: main 메소드는 반환값이 없어야 함
#
#  즉, 아무것도 반환하지 않음
#
# **main**: 메소드의 이름은 반드시 "main"이어야 함
#
# 이것은 JVM(Java Virtual Machine)이 프로그램을 시작할 때 찾아 실행하는 특별한 이름
#
# **String[] args**: main 메소드의 매개변수로 문자열 배열을 받음
#
# 이 배열은 명령행 인수(command line arguments)를 저장하는 데 사용됨
#
# 프로그램을 실행할 때 명령행에서 전달된 인수들은 이 배열에 저장되어 프로그램 내에서 활용할 수 있음

# %% [markdown]
# # **Static**
# ```
# Java에서 Static 키워드를 사용한다는 것은
#  메모리에 한번 할당되어 프로그램이 종료될 때 해제되는 것
#
# 메모리에 한번 할당되므로 여러 객체가 해당 메모리를 공유
# ```
#
# 우리가 만든 Class는 Static 영역에 생성되고, new 연산을 통해 생성한 객체는 Heap영역에 생성
#
# 객체의 생성시에 할당된 Heap영역의 메모리는 Garbage Collector를 통해 수시로 관리를 받음
#
# 하지만 Static 키워드를 통해 Static 영역에 할당된 메모리는 모든 객체가 공유하는 메모리라는 장점을 지니지만,
# Garbage Collector의 관리 영역 밖에 존재하므로 Static을 자주 사용하면 프로그램의 종료시까지 메모리가 할당된 채로 존재하므로 자주 사용하게 되면 시스템의 퍼포먼스에 악영향을 주게 됨
#
# # **Static 변수 특징**
#
# Static 변수는 클래스 변수
#
# 객체를 생성하지 않고도 Static 자원에 접근이 가능
#
#
# # **void**
#
# void의 역할은 return 되는 타입이 없음을 의미
#
#  즉 아무것도 리턴하지 않음을 선언해주는 것
#
#  아무것도 리턴하지 않아야 에러가 발생하지 않음

# %% [markdown]
#
#     public class MainClass {
#
#      public static void main(String[] args) {
#
#           MyCalculator calculator = new  MyCalculator();
#           calculator.calAdd(10, 5);
#           calculator.calSub(10, 5);
#           calculator.calMul(10, 5);
#           calculator.calDiv(10, 5);
#       }
#     }
#
# **MyCalculator**는 클래스의 이름
#
# **calculator**는 변수의 이름
#
# **new MyCalculator()**는 MyCalculator 클래스의 새로운 인스턴스를 생성하는 코드
# ```
# MyCalculator 클래스의 새로운 객체를 생성
# 이 객체는 calculator라는 변수에 할당됨
# 이렇게 하면 calculator 변수가
# MyCalculator 클래스의 인스턴스를 가리키게 되어
# 해당 인스턴스의 메소드와 속성에 접근할 수 있음
# 이후에 calculator 변수를 사용하여
# MyCalculator 클래스의 메소드를 호출하거나 클래스의 속성을 조작할 수 있음
# ```

# %% [markdown]
# ```
# public interface ICalculator {
#
#   public int doOperation(int firstNum, int secondNum);
# }
# ```
# # **Interface의 역할**
#
# **인터페이스**는 public int doOperation(int firstNum, int secondNum);와 같은 **메서드를 선언하는 역할**을 함
#
# 이 메서드는 int 타입의 firstNum과 secondNum 두 개의 정수 매개변수를 받고, 정수를 반환하는 메서드
#
# 클래스가 이 인터페이스를 구현하면, 해당 클래스는 doOperation **메서드를 구현해야 함** 이것은 인터페이스의 메서드 목록을 구현한 클래스가 반드시 제공해야 하는 기능을 나타냄
#
# 인터페이스를 사용하면 다른 클래스가 동일한 인터페이스를 구현할 수 있으므로, **다형성을 지원**함
#
# 이것은 코드의 유연성을 높이고 여러 클래스가 동일한 인터페이스를 사용하여 상호 교체 가능하도록 함

# %% [markdown]
# ```
# public class CalAdd implements ICalculator {
#     @Override
#     public int doOperation(int firstNum, int secondNum)  {
#         return firstNum + secondNum;
#     }
# }
# ```
# # **implements의 역할**
#
# implements 키워드를 사용하여 클래스가 특정 **인터페이스를 구현**한다고 선언
#
#  여기서 CalAdd 클래스는 ICalculator 인터페이스를 구현하고 있으므로,
#
#  해당 클래스는 ICalculator 인터페이스에서 정의된 메서드를 제공해야 함
#
# **강제 메서드 구현**
#
# 인터페이스를 구현하는 클래스는 인터페이스에 정의된 모든 메서드를 구현해야 함
#
#  이 경우 ICalculator 인터페이스에는 doOperation 메서드가 정의되어 있으므로,
#
#   CalAdd 클래스는 doOperation 메서드를 구현해야 합니다

# %% [markdown]
# # **DI(Dependency Injection) / 의존성 주입**
#
# **필요한(의존하는) 객체를 직접 생성하지 않고 외부에서 주입하는
# 방식**

# %% [markdown]
# # **this**
# 인스턴스 자신을 의미
#
# 객체 전역에서 접근할 수 있는 객체 안에 담기는 변수가 됨

# %% [markdown]
# # **자바빈 (JavaBean)**
#
# 자바로 작성된 클래스(class)
# ```
# 자바빈 클래스에는 파라미터가 없는 생성자가
#  반드시 있어야 하며,
#  클래스 외부에서 필드에 접근할 때에는
#  반드시 메소드를 통하여 접근해야 하며
#  이 때 get, set 으로 시작하는 메소드를 이용
# ```
#
# 객체지향 언어인 자바에서
# **객체**는 고유한 속성(특징)을 가지는데,
#
# 그 속성을 칭하는 단어를 **프로퍼티(property)**라고 한다.
# 그리고 이 속성의 진짜 모습, 즉 '실체'를 담는 곳이 **필드(field, 멤버변수)**이다
#
#
#  **프로퍼티(property)**
#  ```
# 프로퍼티는 useBean의 대상이 되는 객체의 set 메서드와 get 메서드로
# jsp에서 호출할 때는 set과 get은 빼고,
# 나머지 메서드명을 소문자로 만들어 지칭한다.
# 일반적으로 접근 제어자는 public을 사용하여 접근해
# 사용 가능하다.
# ```
# **필드(field)**
# ```
# 필드의 경우 useBean의 대상이 되는 클래스의 class변수/ 상수를 의미하고
# 일반적으로 접근제어자가 private 이기에 직접적인 접근을 할 수 없다.
# ```

# %% [markdown]
# 자바에서 DAO (Data Access Object)와
# DTO (Data Transfer Object)는 데이터베이스와 애플리케이션 간 데이터 처리를
# 효과적으로 관리하기 위한 패턴 및 개념
# 이 두 개체는 데이터베이스 연동과 데이터 전달에
# 관련된 역할을 분리하여
# 애플리케이션을 더 모듈화하고 유지보수를 쉽게 만들어줌
#
# 일반적으로 DAO는 데이터베이스와의 상호 작용을 캡슐화하고, DTO는 데이터 전달을 위한 구조화된 데이터 객체를 정의하는 데 사용됨. 이러한 패턴과 개념은 코드의 재사용성과 유지보수성을 높이고, 데이터 액세스와 데이터 전달을 분리하여 코드를 더 깔끔하고 확장 가능하게 만들어줌
#
# # **DAO(Data Access Object)**
# * DAO는 데이터베이스와의 상호 작용을 추상화하는 객체 지향 패턴
# * 주로 데이터베이스에 접근하고 데이터를 조작하는 메서드를 정의
# *DAO는 데이터베이스 연결, 쿼리 실행, 결과 처리 등과 같은 데이터 액세스 관련 작업을 담당
# * 애플리케이션의 비즈니스 로직 레이어와 데이터베이스 레이어 사이에서 중개자 역할을 수행
#
# # **DTO (Data Transfer Object)**
# * DTO는 데이터를 애플리케이션의 다른 부분으로 전달하기 위한 객체
# * 주로 데이터베이스로부터 읽은 데이터나 애플리케이션 간에 전송할 데이터의 구조를 정의하는데 사용
# *DTO는 특정 비즈니스 엔티티의 필드 값을 포함하며, getter와 setter 메서드를 통해 데이터에 접근 및 수정할 수 있음
# *DTO는 데이터 전달의 목적으로 사용되며, 데이터를 전송하거나 뷰에서 데이터를 표시하는 데 자주 활용
#
#
# # **VO(Value Object)**
#
# 데이터를 나타내는 데 사용되는 객체
#
# 주로 데이터를 캡슐화하고 읽기 전용(getter) 속성을 제공하는 목적으로 설계됨
# VO는 데이터를 가지고 있는 간단한 자바 클래스로, 데이터를 표현하고 전달하기 위한 목적으로 사용됨
#
# **데이터 캡슐화**: VO는 데이터 필드를 비공개(private)로 선언하고, public getter 메서드를 통해 데이터에 접근할 수 있도록 제공함
#
# 이렇게 하면 데이터의 무결성을 보존하고 데이터를 보호할 수 있습니다.
#
# **불변성**: VO는 일반적으로 불변 객체로 설계됨
#
#  즉, 한 번 생성된 후에는 내부 데이터를 변경할 수 없도록 만들어짐
#
#  이는 데이터의 안정성과 예측 가능한 동작을 보장
#
# **비즈니스 로직과 분리**: VO는 주로 데이터를 표현하기 위한 목적으로 사용되므로 비즈니스 로직을 가지고 있지 않음
#
# 이는 데이터와 비즈니스 로직을 분리하여 코드를 더 모듈화하고 유지보수하기 쉽게 만듦
#
# **데이터 전달**: VO는 데이터를 다른 부분으로 전달하거나 반환하는 데 사용됨
#
# 주로 메서드의 반환 값이나 메서드의 매개변수로 활용됨
